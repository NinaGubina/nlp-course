# %% [markdown]
# ##### Implementation of n-gram model:
# 1. Process text: split into sentences and tokens, augment sentences with n-1 SOS tokens and one EOS token. Optionally, you can only replace rare words with token UNK.
# 2. Compute n-grams from your text
# 3. Compute probabilities for your n-grams using smoothing
# 4. using formula for n-gram, generate several sentences

# %%
import re
import requests
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize 
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
import math

# %%
def clean_text(paragraph, n):
    p = paragraph[n]

    href_pattern = r"<a href=[^>]+>([^<]+)</a>"
    p = re.sub(href_pattern, r"\1", p)

    boldface_pattern = r"<b>([^<]+)</b>"
    p = re.sub(boldface_pattern, r"\1", p)

    italic_pattern = r"<i>([^<]+)</i>"
    p = re.sub(italic_pattern, r"\1", p)

    span_pattern = r"<span\s[^<]+</span>"
    p = re.sub(span_pattern, "", p)

    sup_pattern = r"<sup\s[^<]+</sup>"
    p = re.sub(sup_pattern, "", p)

    return p

# %%
#r = requests.get(url="https://en.wikipedia.org/wiki/Machine_learning")
r = requests.get(url="https://en.wikipedia.org/wiki/Rock_music")
wiki_text = r.text

# %%
paragraph = re.findall(r"<p>(.*)\n", wiki_text)

# %%
# get text
t = []
paragraphs_num = range(len(paragraph))

for n in paragraphs_num:
    p = clean_text(paragraph, n)
    t.append(p)

try:
    t.remove('')
except:
    pass

# %%
SOS = '<s> '
EOS = '</s>'
UNK = '<unk>'

def add_tokens(s, n):
    sos = SOS * (n-1) if n > 1 else SOS
    return ['{}{} {}'.format(sos, sent, EOS) for sent in s]

# %%
# get sentences
s = []
for p in t:
    p_sent_nltk = sent_tokenize(p)
    for sent in p_sent_nltk:    
        s.append(sent)

s = add_tokens(s, 3)
s = [sent.lower() for sent in s]

# %%
def replace_single(w):
    vocab = nltk.FreqDist(w)
    return [token if vocab[token] > 1 else UNK for token in w]

# %%
# get tokens
w = ' '.join(s).split(' ')
w = replace_single(w)

# %%
# get vocabulary
vocab = nltk.FreqDist(w)
vocab
# Out:
# FreqDist({'<unk>': 2878, 'the': 1081, '<s>': 960, 'and': 760, 'of': 507, '</s>': 480, 'in': 337, 'rock': 269, 'a': 261, 'to': 251, ...})

# %%
n = 3
vocab_size = len(vocab)

n_grams = nltk.ngrams(w, n)
n_vocab = nltk.FreqDist(n_grams)

n1_grams = nltk.ngrams(w, n-1)
n1_vocab = nltk.FreqDist(n1_grams)

# %%
def smooth(n_gram, n_count, k, n1_vocab, vocab_size):
    n1_gram = n_gram[:-1]
    n1_count = n1_vocab[n1_gram]
    return -math.log((n_count + k) / (n1_count + k * vocab_size))

# %%
prob = {n_gram: smooth(n_gram, c, 1, n1_vocab, vocab_size) for n_gram, c in n_vocab.items()}
prob
# Out:
# {('<s>', '<s>', 'rock'): 4.791926339849912,
#  ('<s>', 'rock', 'is'): 6.508769136971682,
#  ('rock', 'is', 'a'): 6.501289670540389,
#  ('is', 'a', 'broad'): 6.503539390274405,
#  ('a', 'broad', 'genre'): 6.499787040655854,
#  ('broad', 'genre', 'of'): 6.4990348781533,
#  ('genre', 'of', 'popular'): 6.501289670540389,
#  ('of', 'popular', 'music'): 6.501289670540389,
#  ('popular', 'music', 'that'): 6.09732493780746,
#  ('music', 'that', 'originated'): 6.501289670540389,
#  ('that', 'originated', 'as'): 6.4990348781533,
#  ('originated', 'as', '"rock'): 6.4990348781533,
#  ('as', '"rock', 'and'): 6.4990348781533,
#  ('"rock', 'and', 'roll"'): 5.808142489980444,
#  ('and', 'roll"', 'in'): 6.501289670540389,
#  ('roll"', 'in', 'the'): 6.4990348781533,
#  ('in', 'the', 'united'): 4.99991133073328,
#  ('the', 'united', 'states'): 5.256006168476314,
#  ('united', 'states', 'in'): 6.502790045915623,
#  ('states', 'in', 'the'): 6.4990348781533,
#  ('in', 'the', 'late'): 4.663439094112067,
#  ('the', 'late', '1940s'): 6.115156019450532,
#  ('late', '1940s', 'and'): 6.09432193254769,
#  ('1940s', 'and', 'early'): 6.095073529727002,
#  ('and', 'early', '1950s,'): 6.102558594613569,
#  ('early', '1950s,', 'developing'): 6.500538637835167,
#  ('1950s,', 'developing', 'into'): 6.4990348781533,
#  ('developing', 'into', 'a'): 6.4990348781533,
#  ('into', 'a', 'range'): 6.503539390274405,
#  ('a', 'range', 'of'): 6.4990348781533,
#  ('range', 'of', 'different'): 6.502040139618764,
#  ('of', 'different', 'styles'): 6.499787040655854,
#  ('different', 'styles', 'from'): 6.4990348781533,
#  ('styles', 'from', 'the'): 6.4990348781533,
#  ('from', 'the', 'mid-1960s,'): 6.530148499002369,
#  ('the', 'mid-1960s,', 'particularly'): 6.499787040655854,
#  ('mid-1960s,', 'particularly', 'in'): 6.4990348781533,
#  ('particularly', 'in', 'the'): 5.808142489980444,
#  ('united', 'states', 'and'): 5.809642865355679,
#  ('states', 'and', 'the'): 6.095073529727002,
#  ('and', 'the', 'united'): 5.87282176697721,
#  ('the', 'united', 'kingdom.'): 6.103304028863517,
#  ('united', 'kingdom.', '</s>'): 6.09432193254769,
#  ('kingdom.', '</s>', '<s>'): 6.09432193254769,
#  ('</s>', '<s>', '<s>'): 1.3256371866902918,
#  ('<s>', '<s>', 'it'): 4.791926339849912,
#  ('<s>', 'it', 'has'): 5.815621956411737,
#  ('it', 'has', 'its'): 6.507277712385012,
#  ('has', 'its', 'roots'): 6.4990348781533,
#  ('its', 'roots', 'in'): 6.4990348781533,
#  ('roots', 'in', '1940s'): 6.4990348781533,
#  ('in', '1940s', 'and'): 6.4990348781533,
#  ('1940s', 'and', '1950s'): 6.500538637835167,
#  ('and', '1950s', 'rock'): 6.4990348781533,
#  ('1950s', 'rock', 'and'): 6.09432193254769,
#  ('rock', 'and', 'roll,'): 5.293304824724492,
#  ('and', 'roll,', 'a'): 6.502790045915623,
#  ('roll,', 'a', 'style'): 6.4990348781533,
#  ('a', 'style', 'that'): 6.499787040655854,
#  ('style', 'that', 'drew'): 6.4990348781533,
#  ('that', 'drew', 'directly'): 6.499787040655854,
#  ('drew', 'directly', 'from'): 6.4990348781533,
#  ('directly', 'from', 'the'): 6.499787040655854,
#  ('from', 'the', 'blues'): 6.124683390894205,
#  ('the', 'blues', 'and'): 6.499787040655854,
#  ('blues', 'and', 'rhythm'): 6.502040139618764,
#  ('and', 'rhythm', 'and'): 6.09432193254769,
#  ('rhythm', 'and', 'blues'): 5.251525205041278,
#  ('and', 'blues', 'genres'): 6.505036396541998,
#  ('blues', 'genres', 'of'): 6.4990348781533,
#  ('genres', 'of', 'african-american'): 6.500538637835167,
#  ('of', 'african-american', 'music'): 6.4990348781533,
#  ('african-american', 'music', 'and'): 6.4990348781533,
#  ('music', 'and', 'from'): 6.505036396541998,
#  ('and', 'from', 'country'): 6.4990348781533,
#  ('from', 'country', 'music.'): 6.4990348781533,
#  ('country', 'music.', '</s>'): 6.4990348781533,
#  ('music.', '</s>', '<s>'): 4.5621135536664195,
#  ('<s>', 'rock', 'also'): 6.508769136971682,
#  ('rock', 'also', 'drew'): 6.4990348781533,
#  ('also', 'drew', 'strongly'): 6.4990348781533,
#  ('drew', 'strongly', 'from'): 6.4990348781533,
#  ('strongly', 'from', 'genres'): 6.4990348781533,
#  ('from', 'genres', 'such'): 6.4990348781533,
#  ('genres', 'such', 'as'): 5.807391457275221,
#  ('such', 'as', 'electric'): 6.542471960506805,
#  ('as', 'electric', 'blues'): 6.4990348781533,
#  ('electric', 'blues', 'and'): 6.499787040655854,
#  ('blues', 'and', 'folk,'): 6.502040139618764,
#  ('and', 'folk,', 'and'): 6.4990348781533,
#  ('folk,', 'and', 'incorporated'): 6.4990348781533,
#  ('and', 'incorporated', 'influences'): 6.4990348781533,
#  ('incorporated', 'influences', 'from'): 6.4990348781533,
#  ('influences', 'from', 'jazz'): 6.499787040655854,
#  ('from', 'jazz', 'and'): 6.4990348781533,
#  ('jazz', 'and', 'other'): 6.501289670540389,
#  ('and', 'other', 'musical'): 6.502040139618764,
#  ('other', 'musical', 'styles.'): 6.500538637835167,
#  ('musical', 'styles.', '</s>'): 6.4990348781533,
#  ('styles.', '</s>', '<s>'): 5.584998938666234,
#  ('<s>', '<s>', 'for'): 6.113682179832232,
#  ('<s>', 'for', 'instrumentation,'): 6.500538637835167,
#  ('for', 'instrumentation,', 'rock'): 6.4990348781533,
#  ('instrumentation,', 'rock', 'has'): 6.4990348781533,
#  ('rock', 'has', 'centered'): 6.505036396541998,
#  ('has', 'centered', 'on'): 6.4990348781533,
#  ('centered', 'on', 'the'): 5.808142489980444,
#  ('on', 'the', 'electric'): 6.108506567539647,
#  ('the', 'electric', 'guitar,'): 5.584998938666234,
#  ('electric', 'guitar,', 'usually'): 6.502040139618764,
#  ('guitar,', 'usually', 'as'): 6.4990348781533,
#  ('usually', 'as', 'part'): 6.4990348781533,
#  ('as', 'part', 'of'): 5.584998938666234,
#  ('part', 'of', 'a'): 6.09732493780746,
#  ('of', 'a', 'rock'): 6.505784060128229,
#  ('a', 'rock', 'group'): 6.501289670540389,
#  ('rock', 'group', 'with'): 6.4990348781533,
#  ('group', 'with', 'electric'): 6.4990348781533,
#  ('with', 'electric', 'bass'): 6.4990348781533,
#  ('electric', 'bass', 'guitar,'): 6.09432193254769,
#  ('bass', 'guitar,', '<unk>'): 6.499787040655854,
#  ('guitar,', '<unk>', 'and'): 6.4990348781533,
#  ('<unk>', 'and', 'one'): 6.714170529909472,
#  ('and', 'one', 'or'): 6.4990348781533,
#  ('one', 'or', 'more'): 5.807391457275221,
#  ('or', 'more', '<unk>'): 6.095073529727002,
#  ('more', '<unk>', '</s>'): 5.820824495087865,
#  ('<unk>', '</s>', '<s>'): 1.7719568419318752,
#  ('<s>', '<s>', '<unk>'): 3.7623069226687536,
#  ('<s>', '<unk>', 'rock'): 6.12322353662034,
#  ('<unk>', 'rock', 'is'): 6.517671272912275,
#  ('rock', 'is', '<unk>'): 6.501289670540389,
#  ('is', '<unk>', 'music'): 6.501289670540389,
#  ('<unk>', 'music', 'with'): 6.505036396541998,
#  ('music', 'with', 'a'): 6.499787040655854,
#  ('with', 'a', '<a'): 6.507277712385012,
#  ('a', '<a', '<unk>'): 6.4990348781533,
#  ('<a', '<unk>', '<unk>'): 6.4990348781533,
#  ('<unk>', '<unk>', '<unk>'): 2.3316016359730853,
#  ('<unk>', '<unk>', 'class="music-symbol"'): 6.921658184151128,
#  ('<unk>', 'class="music-symbol"', 'style="font-family:'): 6.09432193254769,
#  ('class="music-symbol"', 'style="font-family:', 'arial'): 6.09432193254769,
#  ('style="font-family:', 'arial', 'unicode'): 6.09432193254769,
#  ('arial', 'unicode', 'ms,'): 6.09432193254769,
#  ('unicode', 'ms,', 'lucida'): 6.09432193254769,
#  ('ms,', 'lucida', 'sans'): 6.09432193254769,
#  ('lucida', 'sans', 'unicode;"><span'): 6.09432193254769,
#  ('sans', 'unicode;"><span', 'class="serif-fonts"'): 6.09432193254769,
#  ('unicode;"><span',
#   'class="serif-fonts"',
#   'style="font-family:'): 6.09432193254769,
#  ('class="serif-fonts"',
#   'style="font-family:',
#   '&#39;georgia'): 6.09432193254769,
#  ('style="font-family:', '&#39;georgia', 'pro&#39;,'): 6.09432193254769,
#  ('&#39;georgia', 'pro&#39;,', 'georgia,'): 6.09432193254769,
#  ('pro&#39;,', 'georgia,', '&#39;dejavu'): 6.09432193254769,
#  ('georgia,', '&#39;dejavu', 'serif&#39;,'): 6.09432193254769,
#  ('&#39;dejavu', 'serif&#39;,', 'times,'): 6.09432193254769,
#  ('serif&#39;,', 'times,', '&#39;times'): 6.09432193254769,
#  ('times,', '&#39;times', 'new'): 6.09432193254769,
#  ('&#39;times', 'new', 'roman&#39;,'): 6.09432193254769,
#  ('new', 'roman&#39;,', 'freeserif,'): 6.09432193254769,
#  ('roman&#39;,', 'freeserif,', '&#39;dejavu'): 6.09432193254769,
#  ('freeserif,', '&#39;dejavu', 'math'): 6.09432193254769,
#  ('&#39;dejavu', 'math', 'tex&#39;,'): 6.09432193254769,
#  ('math', 'tex&#39;,', '&#39;urw'): 6.09432193254769,
#  ('tex&#39;,', '&#39;urw', 'bookman'): 6.09432193254769,
#  ('&#39;urw', 'bookman', 'l&#39;,'): 6.09432193254769,
#  ('bookman', 'l&#39;,', 'serif;"><span'): 6.09432193254769,
#  ('l&#39;,',
#   'serif;"><span',
#   'style="display:inline-block;margin-bottom:-0.3em;vertical-align:-0.4em;line-height:0.85em;font-size:80%;text-align:center"><br'): 6.09432193254769,
#  ('serif;"><span',
#   'style="display:inline-block;margin-bottom:-0.3em;vertical-align:-0.4em;line-height:0.85em;font-size:80%;text-align:center"><br',
#   '/><sub'): 6.09432193254769,
#  ('style="display:inline-block;margin-bottom:-0.3em;vertical-align:-0.4em;line-height:0.85em;font-size:80%;text-align:center"><br',
#   '/><sub',
#   'style="font-size:inherit;line-height:inherit;vertical-align:baseline">4</sub></span></span></span>'): 6.09432193254769,
#  ('/><sub',
#   'style="font-size:inherit;line-height:inherit;vertical-align:baseline">4</sub></span></span></span>',
#   'time'): 6.499787040655854,
#  ('style="font-size:inherit;line-height:inherit;vertical-align:baseline">4</sub></span></span></span>',
#   'time',
#   '<unk>'): 6.4990348781533,
#  ('time', '<unk>', 'using'): 6.499787040655854,
#  ('<unk>', 'using', 'a'): 6.095073529727002,
#  ('using', 'a', 'verse–chorus'): 6.499787040655854,
#  ('a', 'verse–chorus', '<unk>'): 6.4990348781533,
#  ('verse–chorus', '<unk>', 'but'): 6.499787040655854,
#  ('<unk>', 'but', 'the'): 6.100318952020064,
#  ('but', 'the', 'genre'): 6.095073529727002,
#  ('the', 'genre', 'has'): 6.512487995850419,
#  ('genre', 'has', 'become'): 6.499787040655854,
#  ('has', 'become', 'extremely'): 6.4990348781533,
#  ('become', 'extremely', '<unk>'): 6.4990348781533,
#  ('extremely', '<unk>', '</s>'): 6.4990348781533,
#  ('<s>', '<s>', 'like'): 6.401364252284012,
#  ('<s>', 'like', 'pop'): 6.499787040655854,
#  ('like', 'pop', 'music,'): 6.09432193254769,
#  ('pop', 'music,', 'lyrics'): 6.500538637835167,
#  ('music,', 'lyrics', 'often'): 6.4990348781533,
#  ('lyrics', 'often', '<unk>'): 6.4990348781533,
#  ('often', '<unk>', 'romantic'): 6.507277712385012,
#  ('<unk>', 'romantic', 'love'): 6.4990348781533,
#  ('romantic', 'love', 'but'): 6.4990348781533,
#  ('love', 'but', 'also'): 6.4990348781533,
#  ('but', 'also', '<unk>'): 6.4990348781533,
#  ('also', '<unk>', 'a'): 6.501289670540389,
#  ('<unk>', 'a', 'wide'): 6.115892125483034,
#  ('a', 'wide', 'variety'): 6.096575031510599,
#  ('wide', 'variety', 'of'): 6.09432193254769,
#  ('variety', 'of', 'other'): 6.503539390274405,
#  ('of', 'other', 'themes'): 6.501289670540389,
#  ('other', 'themes', 'that'): 6.4990348781533,
#  ('themes', 'that', 'are'): 6.4990348781533,
#  ('that', 'are', 'frequently'): 6.4990348781533,
#  ('are', 'frequently', 'social'): 6.4990348781533,
#  ('frequently', 'social', 'or'): 6.4990348781533,
#  ('social', 'or', '<unk>'): 6.4990348781533,
#  ('or', '<unk>', '</s>'): 6.099571288433833,
#  ('<s>', 'rock', 'was'): 6.508769136971682,
#  ('rock', 'was', 'the'): 6.51025834052315,
#  ('was', 'the', 'most'): 6.506531165131227,
#  ('the', 'most', 'popular'): 6.513230110912307,
#  ('most', 'popular', 'genre'): 6.4990348781533,
#  ('popular', 'genre', 'of'): 6.4990348781533,
#  ('genre', 'of', 'music'): 6.501289670540389,
#  ('of', 'music', 'in'): 6.501289670540389,
#  ('music', 'in', 'the'): 5.58799744166249,
#  ('in', 'the', '<unk>'): 4.257973986003902,
#  ('the', '<unk>', 'and'): 3.731545900432839,
#  ('<unk>', 'and', 'much'): 6.714170529909472,
#  ('and', 'much', 'of'): 6.4990348781533,
#  ('much', 'of', 'the'): 6.095073529727002,
#  ('of', 'the', 'western'): 6.595780513961311,
#  ('the', 'western', 'world'): 6.4990348781533,
#  ('western', 'world', 'from'): 6.4990348781533,
#  ('world', 'from', 'the'): 6.4990348781533,
#  ('from', 'the', '1950s'): 6.530148499002369,
#  ('the', '1950s', 'to'): 6.502040139618764,
#  ('1950s', 'to', 'the'): 6.4990348781533,
#  ('to', 'the', '2010s.'): 6.516932447610842,
#  ('the', '2010s.', '</s>'): 6.09432193254769,
#  ('2010s.', '</s>', '<s>'): 6.09432193254769,
#  ('<s>', 'rock', 'musicians'): 6.508769136971682,
#  ('rock', 'musicians', 'in'): 6.500538637835167,
#  ('musicians', 'in', 'the'): 6.499787040655854,
#  ('in', 'the', 'mid-1960s'): 5.916202062607435,
#  ('the', 'mid-1960s', 'began'): 6.502040139618764,
#  ('mid-1960s', 'began', 'to'): 6.4990348781533,
#  ('began', 'to', '<unk>'): 4.811444983804539,
#  ('to', '<unk>', 'the'): 5.159055299214529,
#  ('<unk>', 'the', 'album'): 6.577861357721047,
#  ('the', 'album', '<unk>'): 5.404177757247514,
#  ('album', '<unk>', 'of'): 5.817854930916049,
#  ('<unk>', 'of', 'the'): 3.9209485710336502,
#  ('of', 'the', 'single'): 6.595780513961311,
#  ('the', 'single', 'as'): 6.500538637835167,
#  ('single', 'as', 'the'): 6.4990348781533,
#  ('as', 'the', 'dominant'): 6.1129444446456915,
#  ('the', 'dominant', 'form'): 6.095073529727002,
#  ('dominant', 'form', 'of'): 6.09432193254769,
#  ('form', 'of', 'recorded'): 6.102558594613569,
#  ('of', 'recorded', 'music'): 6.09432193254769,
#  ('recorded', 'music', 'expression'): 6.09432193254769,
#  ('music', 'expression', 'and'): 6.09432193254769,
#  ('expression', 'and', 'consumption,'): 6.09432193254769,
#  ('and', 'consumption,', 'with'): 6.499787040655854,
#  ('consumption,', 'with', 'the'): 6.4990348781533,
#  ('with', 'the', 'beatles'): 6.519884479274924,
#  ('the', 'beatles', 'at'): 6.502790045915623,
#  ('beatles', 'at', 'the'): 6.4990348781533,
#  ('at', 'the', '<unk>'): 5.8118892159820525,
#  ('the', '<unk>', 'of'): 3.784189633918261,
#  ('<unk>', 'of', 'this'): 6.595097220460179,
#  ('of', 'this', 'development.'): 6.499787040655854,
#  ('this', 'development.', '</s>'): 6.4990348781533,
#  ('development.', '</s>', '<s>'): 6.09432193254769,
#  ('<s>', '<s>', 'their'): 5.708217071724067,
#  ('<s>', 'their', '<unk>'): 5.808892959058818,
#  ('their', '<unk>', '<unk>'): 5.413133040976618,
#  ('<unk>', '<unk>', 'the'): 4.28260085453587,
#  ('<unk>', 'the', 'genre'): 5.661570625846892,
#  ('the', 'genre', 'a'): 6.512487995850419,
#  ('genre', 'a', 'cultural'): 6.4990348781533,
#  ('a', 'cultural', 'legitimacy'): 6.4990348781533,
#  ('cultural', 'legitimacy', 'in'): 6.09432193254769,
#  ('legitimacy', 'in', 'the'): 6.09432193254769,
#  ('in', 'the', 'mainstream'): 6.60934924316738,
#  ('the', 'mainstream', 'and'): 5.8111409929767,
#  ('mainstream', 'and', '<unk>'): 6.501289670540389,
#  ('and', '<unk>', 'a'): 5.949339620807311,
#  ('<unk>', 'a', 'rock-informed'): 6.115892125483034,
#  ('a', 'rock-informed', 'album'): 6.09432193254769,
#  ('rock-informed', 'album', 'era'): 6.09432193254769,
#  ('album', 'era', 'in'): 6.09432193254769,
#  ('era', 'in', 'the'): 6.09432193254769,
#  ('in', 'the', 'music'): 5.51073695449927,
#  ('the', 'music', 'industry'): 6.09807428216624,
#  ('music', 'industry', 'for'): 6.09432193254769,
#  ('industry', 'for', 'the'): 6.09432193254769,
#  ('for', 'the', 'next'): 6.10553700336783,
#  ('the', 'next', 'several'): 6.095824562432225,
#  ('next', 'several', 'decades.'): 6.09432193254769,
#  ('several', 'decades.', '</s>'): 6.09432193254769,
#  ('decades.', '</s>', '<s>'): 6.09432193254769,
#  ('<s>', '<s>', 'by'): 4.727387818712341,
#  ('<s>', 'by', 'the'): 5.0054366191870185,
#  ('by', 'the', 'late'): 5.616043560348194,
#  ('the', 'late', '1960s'): 5.422008838890586,
#  ('late', '1960s', '<unk>'): 6.502040139618764,
#  ('1960s', '<unk>', 'rock"'): 6.4990348781533,
#  ('<unk>', 'rock"', 'period,'): 6.499787040655854,
#  ('rock"', 'period,', 'a'): 6.4990348781533,
#  ('period,', 'a', 'number'): 6.4990348781533,
#  ('a', 'number', 'of'): 5.584998938666234,
#  ('number', 'of', 'distinct'): 6.096575031510599,
#  ('of', 'distinct', 'rock'): 6.499787040655854,
#  ('distinct', 'rock', 'music'): 6.4990348781533,
#  ('rock', 'music', 'subgenres'): 6.520621127558696,
#  ('music', 'subgenres', 'had'): 6.4990348781533,
#  ('subgenres', 'had', 'emerged,'): 6.4990348781533,
#  ('had', 'emerged,', 'including'): 6.4990348781533,
#  ('emerged,', 'including', '<unk>'): 6.499787040655854,
#  ('including', '<unk>', 'like'): 6.506531165131227,
#  ('<unk>', 'like', 'blues'): 6.502040139618764,
#  ('like', 'blues', 'rock,'): 6.4990348781533,
#  ('blues', 'rock,', 'folk'): 6.500538637835167,
#  ('rock,', 'folk', 'rock,'): 6.4990348781533,
#  ('folk', 'rock,', 'country'): 6.499787040655854,
#  ('rock,', 'country', 'rock,'): 6.499787040655854,
#  ('country', 'rock,', 'southern'): 6.4990348781533,
#  ('rock,', 'southern', 'rock,'): 6.4990348781533,
#  ('southern', 'rock,', '<unk>'): 6.4990348781533,
#  ('rock,', '<unk>', 'rock,'): 6.501289670540389,
#  ('<unk>', 'rock,', 'and'): 6.501289670540389,
#  ('rock,', 'and', 'jazz'): 6.501289670540389,
#  ('and', 'jazz', 'rock,'): 6.4990348781533,
#  ('jazz', 'rock,', 'which'): 6.4990348781533,
#  ('rock,', 'which', '<unk>'): 6.501289670540389,
#  ('which', '<unk>', 'to'): 6.502790045915623,
#  ('<unk>', 'to', 'the'): 4.754308323991806,
#  ('to', 'the', 'development'): 6.516932447610842,
#  ('the', 'development', 'of'): 5.403427850950654,
#  ('development', 'of', 'psychedelic'): 6.502040139618764,
#  ('of', 'psychedelic', 'rock,'): 6.4990348781533,
#  ('psychedelic', 'rock,', 'influenced'): 6.4990348781533,
#  ('rock,', 'influenced', 'by'): 6.4990348781533,
#  ('influenced', 'by', 'the'): 5.591732970847578,
#  ('by', 'the', '<unk>'): 5.279571323726981,
#  ('the', '<unk>', 'psychedelic'): 6.70196036600254,
#  ('<unk>', 'psychedelic', 'and'): 6.4990348781533,
#  ('psychedelic', 'and', '<unk>'): 6.499787040655854,
#  ('and', '<unk>', 'scene.'): 6.642486801367256,
#  ('<unk>', 'scene.', '</s>'): 6.4990348781533,
#  ('scene.', '</s>', '<s>'): 5.584998938666234,
#  ('<s>', '<s>', 'new'): 6.113682179832232,
#  ('<s>', 'new', 'genres'): 6.500538637835167,
#  ('new', 'genres', 'that'): 6.4990348781533,
#  ('genres', 'that', 'emerged'): 6.499787040655854,
#  ('that', 'emerged', 'included'): 6.499787040655854,
#  ('emerged', 'included', 'progressive'): 6.4990348781533,
#  ('included', 'progressive', 'rock'): 6.4990348781533,
#  ('progressive', 'rock', 'with'): 6.502040139618764,
#  ('rock', 'with', 'extended'): 6.502040139618764,
#  ('with', 'extended', 'artistic'): 6.4990348781533,
#  ('extended', 'artistic', '<unk>'): 6.4990348781533,
#  ('artistic', '<unk>', 'glam'): 6.500538637835167,
#  ('<unk>', 'glam', 'rock,'): 6.4990348781533,
#  ('glam', 'rock,', '<unk>'): 6.4990348781533,
#  ('rock,', '<unk>', 'showmanship'): 6.501289670540389,
#  ('<unk>', 'showmanship', 'and'): 6.4990348781533,
#  ('showmanship', 'and', 'visual'): 6.499787040655854,
#  ('and', 'visual', 'style.'): 6.4990348781533,
#  ('visual', 'style.', '</s>'): 6.4990348781533,
#  ('style.', '</s>', '<s>'): 6.09432193254769,
#  ('<s>', '<s>', 'in'): 3.889058628307897,
#  ('<s>', 'in', 'the'): 4.327805080507242,
#  ('in', 'the', 'second'): 6.203884135059216,
#  ('the', 'second', 'half'): 6.095073529727002,
#  ('second', 'half', 'of'): 6.09432193254769,
#  ('half', 'of', 'the'): 6.09432193254769,
#  ('of', 'the', '1970s,'): 6.1903154058531475,
#  ('the', '1970s,', 'punk'): 6.502040139618764,
#  ('1970s,', 'punk', 'rock'): 6.4990348781533,
#  ('punk', 'rock', 'reacted'): 6.503539390274405,
#  ('rock', 'reacted', 'by'): 6.4990348781533,
#  ('reacted', 'by', 'producing'): 6.4990348781533,
#  ('by', 'producing', '<unk>'): 6.4990348781533,
#  ('producing', '<unk>', '<unk>'): 6.4990348781533,
#  ('<unk>', '<unk>', 'social'): 6.921658184151128,
#  ('<unk>', 'social', 'and'): 6.500538637835167,
#  ('social', 'and', 'political'): 6.095073529727002,
#  ('and', 'political', '<unk>'): 6.09432193254769,
#  ('political', '<unk>', '</s>'): 6.096575031510599,
#  ('<s>', '<s>', 'punk'): 5.554066391896809,
#  ('<s>', 'punk', 'was'): 6.502790045915623,
#  ('punk', 'was', 'an'): 6.4990348781533,
#  ('was', 'an', 'influence'): 6.499787040655854,
#  ('an', 'influence', 'in'): 6.499787040655854,
#  ('influence', 'in', 'the'): 6.4990348781533,
#  ('in', 'the', '1980s'): 5.51073695449927,
#  ('the', '1980s', 'on'): 6.504288173536645,
#  ('1980s', 'on', 'new'): 6.4990348781533,
#  ('on', 'new', 'wave,'): 6.4990348781533,
#  ('new', 'wave,', 'post-punk'): 6.095073529727002,
#  ('wave,', 'post-punk', 'and'): 6.09432193254769,
#  ('post-punk', 'and', 'eventually'): 6.499787040655854,
#  ('and', 'eventually', 'alternative'): 6.4990348781533,
#  ('eventually', 'alternative', 'rock.'): 6.4990348781533,
#  ('alternative', 'rock.', '</s>'): 6.4990348781533,
#  ('rock.', '</s>', '<s>'): 4.030546507612253,
#  ('<s>', '<s>', 'from'): 5.015069891164122,
#  ('<s>', 'from', 'the'): 5.25376819663586,
#  ('from', 'the', '1990s,'): 6.530148499002369,
#  ('the', '1990s,', 'alternative'): 6.499787040655854,
#  ('1990s,', 'alternative', 'rock'): 6.4990348781533,
#  ('alternative', 'rock', 'began'): 6.508023702721733,
#  ('rock', 'began', 'to'): 5.807391457275221,
#  ('to', '<unk>', 'rock'): 6.139884552226255,
#  ('<unk>', 'rock', 'music'): 5.264908304416907,
#  ('rock', 'music', 'and'): 5.827473946998751,
#  ('music', 'and', 'break'): 6.505036396541998,
#  ('and', 'break', 'into'): 6.499787040655854,
#  ('break', 'into', 'the'): 6.4990348781533,
#  ('into', 'the', 'mainstream'): 5.258239142980626,
#  ('the', 'mainstream', 'in'): 6.098823065428482,
#  ('mainstream', 'in', 'the'): 6.09432193254769,
#  ('in', 'the', 'form'): 6.60934924316738,
#  ('the', 'form', 'of'): 6.09432193254769,
#  ('form', 'of', 'grunge,'): 6.508023702721733,
#  ('of', 'grunge,', 'britpop,'): 6.500538637835167,
#  ('grunge,', 'britpop,', 'and'): 6.4990348781533,
#  ('britpop,', 'and', 'indie'): 6.4990348781533,
#  ('and', 'indie', 'rock.'): 6.4990348781533,
#  ('indie', 'rock.', '</s>'): 6.4990348781533,
#  ('<s>', '<s>', 'further'): 6.806829360392176,
#  ('<s>', 'further', 'fusion'): 6.4990348781533,
#  ('further', 'fusion', 'subgenres'): 6.4990348781533,
#  ('fusion', 'subgenres', 'have'): 6.4990348781533,
#  ('subgenres', 'have', 'since'): 6.4990348781533,
#  ('have', 'since', 'emerged,'): 6.4990348781533,
#  ('since', 'emerged,', 'including'): 6.4990348781533,
#  ('emerged,', 'including', 'pop-punk,'): 6.499787040655854,
#  ('including', 'pop-punk,', 'electronic'): 6.4990348781533,
#  ('pop-punk,', 'electronic', 'rock,'): 6.4990348781533,
#  ('electronic', 'rock,', 'rap'): 6.4990348781533,
#  ('rock,', 'rap', 'rock,'): 6.4990348781533,
#  ('rap', 'rock,', 'and'): 6.4990348781533,
#  ('rock,', 'and', 'rap'): 6.501289670540389,
#  ('and', 'rap', 'metal.'): 6.500538637835167,
#  ('rap', 'metal.', '</s>'): 6.4990348781533,
#  ('metal.', '</s>', '<s>'): 6.09432193254769,
#  ('<s>', '<s>', 'some'): 5.420534999272286,
#  ('<s>', 'some', 'movements'): 6.503539390274405,
#  ('some', 'movements', 'were'): 6.4990348781533,
#  ('movements', 'were', '<unk>'): 6.4990348781533,
#  ('were', '<unk>', 'attempts'): 6.509514015963292,
#  ('<unk>', 'attempts', 'to'): 6.4990348781533,
#  ('attempts', 'to', '<unk>'): 5.807391457275221,
#  ('to', '<unk>', "rock's"): 6.139884552226255,
#  ('<unk>', "rock's", '<unk>'): 6.095073529727002,
#  ("rock's", '<unk>', 'including'): 6.500538637835167,
#  ('<unk>', 'including', 'the'): 5.2574953720277815,
#  ('including', 'the', 'garage'): 6.509514015963292,
#  ('the', 'garage', '<unk>'): 6.4990348781533,
#  ('garage', '<unk>', 'revival'): 6.4990348781533,
#  ('<unk>', 'revival', 'in'): 6.499787040655854,
#  ('revival', 'in', 'the'): 6.4990348781533,
#  ('the', '<unk>', '</s>'): 4.21705371621454,
#  ('<s>', '<s>', 'since'): 5.708217071724067,
#  ('<s>', 'since', 'the'): 5.808892959058818,
#  ('since', 'the', '2010s,'): 6.501289670540389,
#  ('the', '2010s,', 'rock'): 6.09432193254769,
#  ('2010s,', 'rock', 'has'): 6.499787040655854,
#  ('rock', 'has', 'lost'): 6.505036396541998,
#  ('has', 'lost', 'its'): 6.4990348781533,
#  ('lost', 'its', 'position'): 6.4990348781533,
#  ('its', 'position', 'as'): 6.09432193254769,
#  ('position', 'as', 'the'): 6.09432193254769,
#  ('as', 'the', '<unk>'): 4.726650083525801,
#  ('the', '<unk>', 'popular'): 6.70196036600254,
#  ('<unk>', 'popular', 'music'): 6.4990348781533,
#  ('popular', 'music', 'genre'): 6.502790045915623,
#  ('music', 'genre', 'in'): 6.4990348781533,
#  ('genre', 'in', 'world'): 6.501289670540389,
#  ('in', 'world', 'culture,'): 6.4990348781533,
#  ('world', 'culture,', 'but'): 6.4990348781533,
#  ('culture,', 'but', '<unk>'): 6.4990348781533,
#  ('but', '<unk>', 'commercially'): 6.500538637835167,
#  ('<unk>', 'commercially', '<unk>'): 6.4990348781533,
#  ('commercially', '<unk>', '</s>'): 6.09432193254769,
#  ('<s>', '<s>', 'the'): 3.1692432006657905,
#  ('<s>', 'the', 'increased'): 6.553220899542516,
#  ('the', 'increased', 'influence'): 6.4990348781533,
#  ('increased', 'influence', 'of'): 6.4990348781533,
#  ('influence', 'of', 'hip-hop'): 6.499787040655854,
#  ('of', 'hip-hop', 'and'): 6.4990348781533,
#  ('hip-hop', 'and', 'electronic'): 6.4990348781533,
#  ('and', 'electronic', 'dance'): 6.500538637835167,
#  ('electronic', 'dance', 'music'): 6.499787040655854,
#  ('dance', 'music', 'can'): 6.4990348781533,
#  ('music', 'can', 'be'): 6.4990348781533,
#  ('can', 'be', 'seen'): 5.250776421779037,
#  ('be', 'seen', 'in'): 5.8111409929767,
#  ('seen', 'in', 'rock'): 6.500538637835167,
#  ('in', 'rock', 'music,'): 6.507277712385012,
#  ('rock', 'music,', 'notably'): 6.502040139618764,
#  ('music,', 'notably', 'in'): 6.4990348781533,
#  ('notably', 'in', 'the'): 6.4990348781533,
#  ('the', '<unk>', 'scene'): 6.70196036600254,
#  ('<unk>', 'scene', 'of'): 6.499787040655854,
#  ('scene', 'of', 'the'): 6.095073529727002,
#  ('of', 'the', 'early'): 5.679489782087156,
#  ('the', 'early', '2010s'): 6.524296251136588,
#  ('early', '2010s', 'and'): 6.4990348781533,
#  ('2010s', 'and', 'the'): 6.500538637835167,
#  ('and', 'the', '<unk>'): 3.2888242145449786,
#  ('the', '<unk>', 'revival'): 6.70196036600254,
#  ('<unk>', 'revival', 'of'): 6.499787040655854,
#  ('revival', 'of', 'the'): 6.499787040655854,
#  ('of', 'the', '<unk>'): 3.82319179172153,
#  ('<s>', '<s>', 'a'): 5.420534999272286,
#  ('<s>', 'a', 'good'): 6.503539390274405,
#  ('a', 'good', '<unk>'): 6.09432193254769,
#  ('good', '<unk>', 'of'): 6.500538637835167,
#  ('<unk>', 'of', 'rock,'): 6.595097220460179,
#  ('of', 'rock,', 'in'): 6.4990348781533,
#  ('rock,', 'in', 'fact,'): 6.4990348781533,
#  ('in', 'fact,', 'is'): 6.4990348781533,
#  ('fact,', 'is', 'that'): 6.4990348781533,
#  ('is', 'that', "it's"): 6.499787040655854,
#  ('that', "it's", 'popular'): 6.4990348781533,
#  ("it's", 'popular', 'music'): 6.4990348781533,
#  ('music', 'that', 'to'): 6.501289670540389,
#  ('that', 'to', 'a'): 6.4990348781533,
#  ('to', 'a', '<unk>'): 5.814130531825066,
#  ('a', '<unk>', '<unk>'): 4.206113074175257,
#  ('<unk>', '<unk>', "doesn't"): 6.516193076042964,
#  ('<unk>', "doesn't", '<unk>'): 6.09432193254769,
#  ("doesn't", '<unk>', 'if'): 6.499787040655854,
#  ('<unk>', 'if', "it's"): 6.4990348781533,
#  ('if', "it's", '<unk>'): 6.4990348781533,
#  ("it's", '<unk>', '</s>'): 6.09432193254769,
#  ('<s>', 'the', 'sound'): 6.147755791434351,
#  ('the', 'sound', 'of'): 5.250027077420255,
#  ('sound', 'of', 'rock'): 6.503539390274405,
#  ('of', 'rock', 'is'): 6.516932447610842,
#  ('rock', 'is', 'traditionally'): 6.501289670540389,
#  ('is', 'traditionally', 'centered'): 6.499787040655854,
#  ('traditionally', 'centered', 'on'): 6.4990348781533,
#  ('on', 'the', 'amplified'): 6.51397167564781,
#  ('the', 'amplified', 'electric'): 6.4990348781533,
#  ('amplified', 'electric', 'guitar,'): 6.4990348781533,
#  ('electric', 'guitar,', 'which'): 6.502040139618764,
#  ('guitar,', 'which', 'emerged'): 6.499787040655854,
#  ('which', 'emerged', 'in'): 6.09432193254769,
#  ('emerged', 'in', 'its'): 6.501289670540389,
#  ('in', 'its', 'modern'): 6.499787040655854,
#  ('its', 'modern', 'form'): 6.4990348781533,
#  ('modern', 'form', 'in'): 6.4990348781533,
#  ('form', 'in', 'the'): 6.4990348781533,
#  ('in', 'the', '1950s'): 5.916202062607435,
#  ('the', '1950s', 'with'): 6.502040139618764,
#  ('1950s', 'with', 'the'): 6.4990348781533,
#  ('with', 'the', 'popularity'): 6.519884479274924,
#  ('the', 'popularity', 'of'): 6.09432193254769,
#  ('popularity', 'of', 'rock'): 6.096575031510599,
#  ('of', 'rock', 'and'): 5.264169479115475,
#  ('rock', 'and', 'roll.'): 5.293304824724492,
#  ('and', 'roll.', '</s>'): 5.250027077420255,
#  ('roll.', '</s>', '<s>'): 5.250027077420255,
#  ('<s>', 'it', 'was'): 5.410156848303572,
#  ('it', 'was', 'also'): 5.815621956411737,
#  ('was', 'also', 'greatly'): 6.502040139618764,
#  ('also', 'greatly', 'influenced'): 6.4990348781533,
#  ('greatly', 'influenced', 'by'): 6.499787040655854,
#  ('by', 'the', 'sounds'): 6.532334292222349,
#  ('the', 'sounds', 'of'): 6.4990348781533,
#  ('sounds', 'of', 'electric'): 6.499787040655854,
#  ('of', 'electric', 'blues'): 6.499787040655854,
#  ('electric', 'blues', '<unk>'): 6.499787040655854,
#  ('blues', '<unk>', '</s>'): 5.809642865355679,
#  ('sound', 'of', 'an'): 6.503539390274405,
#  ('of', 'an', 'electric'): 6.501289670540389,
#  ('an', 'electric', 'guitar'): 6.499787040655854,
#  ('electric', 'guitar', 'in'): 6.4990348781533,
#  ('guitar', 'in', 'rock'): 6.4990348781533,
#  ('in', 'rock', 'music'): 5.5909869805108565,
#  ('rock', 'music', 'is'): 5.827473946998751,
#  ('music', 'is', 'typically'): 6.500538637835167,
#  ('is', 'typically', 'supported'): 6.4990348781533,
#  ('typically', 'supported', 'by'): 6.4990348781533,
#  ('supported', 'by', 'an'): 6.4990348781533,
#  ('by', 'an', 'electric'): 6.501289670540389,
#  ('an', 'electric', 'bass'): 6.499787040655854,
#  ('bass', 'guitar,', 'which'): 6.499787040655854,
#  ('guitar,', 'which', 'pioneered'): 6.499787040655854,
#  ('which', 'pioneered', 'in'): 6.4990348781533,
#  ('pioneered', 'in', 'jazz'): 6.499787040655854,
#  ('in', 'jazz', 'music'): 6.499787040655854,
#  ('jazz', 'music', 'in'): 6.4990348781533,
#  ('in', 'the', 'same'): 5.916202062607435,
#  ('the', 'same', 'era,'): 6.503539390274405,
#  ('same', 'era,', 'and'): 6.4990348781533,
#  ('era,', 'and', 'by'): 6.4990348781533,
#  ('and', 'by', '<unk>'): 6.096575031510599,
#  ('by', '<unk>', 'produced'): 6.520621127558696,
#  ('<unk>', 'produced', 'from'): 6.500538637835167,
#  ('produced', 'from', 'a'): 6.4990348781533,
#  ('from', 'a', 'drum'): 6.500538637835167,
#  ('a', 'drum', '<unk>'): 6.4990348781533,
#  ('drum', '<unk>', 'that'): 6.4990348781533,
#  ('<unk>', 'that', '<unk>'): 5.596939379038152,
#  ('that', '<unk>', 'drums'): 6.508023702721733,
#  ('<unk>', 'drums', 'and'): 6.4990348781533,
#  ('drums', 'and', '<unk>'): 6.095073529727002,
#  ('and', '<unk>', '</s>'): 3.901646777442055,
#  ('<s>', '<s>', 'this'): 5.1973914479580765,
#  ('<s>', 'this', '<unk>'): 6.099571288433833,
#  ('this', '<unk>', 'of'): 6.502790045915623,
#  ('<unk>', 'of', 'instruments'): 6.595097220460179,
#  ('of', 'instruments', 'has'): 6.4990348781533,
#  ('instruments', 'has', 'often'): 6.4990348781533,
#  ('has', 'often', 'been'): 6.09432193254769,
#  ('often', 'been', '<unk>'): 6.499787040655854,
#  ('been', '<unk>', 'by'): 6.099571288433833,
#  ('<unk>', 'by', 'the'): 4.818079729853095,
#  ('by', 'the', 'inclusion'): 6.532334292222349,
#  ('the', 'inclusion', 'of'): 6.09432193254769,
#  ('inclusion', 'of', 'other'): 6.499787040655854,
#  ('of', 'other', 'instruments,'): 6.501289670540389,
#  ('other', 'instruments,', 'particularly'): 6.4990348781533,
#  ('instruments,', 'particularly', '<unk>'): 6.4990348781533,
#  ('particularly', '<unk>', 'such'): 6.501289670540389,
#  ('<unk>', 'such', 'as'): 4.493866116429417,
#  ('such', 'as', 'the'): 4.837723868268379,
#  ('the', '<unk>', 'the'): 5.09252245356844,
#  ('<unk>', 'the', '<unk>'): 3.557436471576684,
#  ('the', '<unk>', '<unk>'): 3.1466123045131265,
#  ('<unk>', '<unk>', 'and'): 2.810784319977817,
#  ('<unk>', 'and', 'the'): 3.495294705041271,
#  ('<s>', 'the', 'basic'): 6.553220899542516,
#  ('the', 'basic', 'rock'): 6.095073529727002,
#  ('basic', 'rock', 'instrumentation'): 6.500538637835167,
#  ('rock', 'instrumentation', 'was'): 6.500538637835167,
#  ('instrumentation', 'was', 'derived'): 6.4990348781533,
#  ('was', 'derived', 'from'): 6.4990348781533,
#  ('derived', 'from', 'the'): 6.502790045915623,
#  ('from', 'the', 'basic'): 6.530148499002369,
#  ('the', 'basic', 'blues'): 6.500538637835167,
#  ('basic', 'blues', 'band'): 6.4990348781533,
#  ('blues', 'band', 'instrumentation'): 6.4990348781533,
#  ('band', 'instrumentation', '<unk>'): 6.4990348781533,
#  ('instrumentation', '<unk>', 'lead'): 6.4990348781533,
#  ('<unk>', 'lead', 'guitar,'): 6.500538637835167,
#  ('lead', 'guitar,', 'second'): 6.4990348781533,
#  ('guitar,', 'second', '<unk>'): 6.4990348781533,
#  ('second', '<unk>', 'instrument,'): 6.499787040655854,
#  ('<unk>', 'instrument,', 'bass,'): 6.4990348781533,
#  ('instrument,', 'bass,', 'and'): 6.4990348781533,
#  ('bass,', 'and', '<unk>'): 6.499787040655854,
#  ('<s>', 'a', 'group'): 6.503539390274405,
#  ('a', 'group', 'of'): 6.4990348781533,
#  ('group', 'of', 'musicians'): 6.500538637835167,
#  ('of', 'musicians', '<unk>'): 6.499787040655854,
#  ('musicians', '<unk>', 'rock'): 6.501289670540389,
#  ('music', 'is', 'termed'): 6.500538637835167,
#  ('is', 'termed', 'as'): 6.4990348781533,
#  ('termed', 'as', 'a'): 6.4990348781533,
#  ('as', 'a', 'rock'): 6.521357233591198,
#  ('a', 'rock', 'band'): 6.095824562432225,
#  ('rock', 'band', 'or'): 6.500538637835167,
#  ('band', 'or', 'a'): 6.4990348781533,
#  ('or', 'a', 'rock'): 6.499787040655854,
#  ('a', 'rock', 'group.'): 6.501289670540389,
#  ('rock', 'group.', '</s>'): 6.4990348781533,
#  ('group.', '</s>', '<s>'): 5.807391457275221,
#  ('<s>', '<unk>', 'it'): 6.12322353662034,
#  ('<unk>', 'it', 'typically'): 6.511745329644728,
#  ('it', 'typically', '<unk>'): 6.4990348781533,
#  ('typically', '<unk>', 'of'): 6.499787040655854,
#  ('<unk>', 'of', 'between'): 6.595097220460179,
#  ('of', 'between', 'three'): 6.4990348781533,
#  ('between', 'three', '(the'): 6.4990348781533,
#  ('three', '(the', 'power'): 6.4990348781533,
#  ('(the', 'power', '<unk>'): 6.4990348781533,
#  ('power', '<unk>', 'and'): 6.500538637835167,
#  ('<unk>', 'and', 'five'): 6.714170529909472,
#  ('and', 'five', '<unk>'): 6.4990348781533,
#  ('five', '<unk>', '</s>'): 6.499787040655854,
#  ('<s>', '<unk>', 'a'): 6.12322353662034,
#  ('<unk>', 'a', 'rock'): 6.521357233591198,
#  ('rock', 'band', '<unk>'): 6.500538637835167,
#  ('band', '<unk>', 'the'): 6.500538637835167,
#  ('<unk>', 'the', 'form'): 6.577861357721047,
#  ('form', 'of', 'a'): 6.508023702721733,
#  ('of', 'a', '<unk>'): 5.8126368795682835,
#  ('a', '<unk>', 'whose'): 6.557488331338734,
#  ('<unk>', 'whose', 'members'): 6.501289670540389,
#  ('whose', 'members', '<unk>'): 6.4990348781533,
#  ('members', '<unk>', 'one'): 6.4990348781533,
#  ('<unk>', 'one', 'or'): 6.501289670540389,
#  ('more', '<unk>', 'including'): 6.51397167564781,
#  ('<unk>', 'including', '<unk>'): 6.51025834052315,
#  ('including', '<unk>', 'lead'): 6.506531165131227,
#  ('<unk>', 'lead', 'guitarist,'): 6.095073529727002,
#  ('lead', 'guitarist,', 'rhythm'): 6.499787040655854,
#  ('guitarist,', 'rhythm', 'guitarist,'): 6.4990348781533,
#  ('rhythm', 'guitarist,', 'bass'): 6.4990348781533,
#  ('guitarist,', 'bass', 'guitarist,'): 6.4990348781533,
#  ('bass', 'guitarist,', '<unk>'): 6.4990348781533,
#  ('guitarist,', '<unk>', 'and'): 6.4990348781533,
#  ('<unk>', 'and', 'often'): 5.797879798035317,
#  ('and', 'often', 'keyboard'): 6.502040139618764,
#  ('often', 'keyboard', 'player'): 6.4990348781533,
#  ('keyboard', 'player', 'or'): 6.500538637835167,
#  ('player', 'or', 'other'): 6.4990348781533,
#  ('or', 'other', '<unk>'): 6.4990348781533,
#  ('other', '<unk>', '</s>'): 6.500538637835167,
#  ('<s>', 'rock', 'music'): 6.103304028863517,
#  ('music', 'is', 'traditionally'): 6.500538637835167,
#  ('is', 'traditionally', 'built'): 6.499787040655854,
#  ('traditionally', 'built', 'on'): 6.4990348781533,
#  ('built', 'on', 'a'): 6.499787040655854,
#  ('on', 'a', '<unk>'): 6.095824562432225,
#  ('a', '<unk>', 'of'): 4.611578182283422,
#  ('<unk>', 'of', 'simple'): 6.595097220460179,
#  ('of', 'simple', '<unk>'): 6.4990348781533,
#  ('simple', '<unk>', '<unk>'): 6.095824562432225,
#  ('<unk>', '<unk>', 'in'): 4.842216642471293,
#  ('<unk>', 'in', 'a'): 5.445299556896683,
#  ('in', 'a', '<unk>'): 5.253021091632861,
#  ('a', '<unk>', 'class="music-symbol"'): 6.557488331338734,
#  ('/><sub',
#   'style="font-size:inherit;line-height:inherit;vertical-align:baseline">4</sub></span></span></span>',
#   '<unk>'): 6.499787040655854,
#  ('style="font-size:inherit;line-height:inherit;vertical-align:baseline">4</sub></span></span></span>',
#   '<unk>',
#   'with'): 6.4990348781533,
#  ('<unk>', 'with', 'a'): 5.616771097666572,
#  ('with', 'a', 'repetitive'): 6.507277712385012,
#  ('a', 'repetitive', '<unk>'): 6.4990348781533,
#  ('repetitive', '<unk>', 'drum'): 6.499787040655854,
#  ('<unk>', 'drum', 'back'): 6.4990348781533,
#  ('drum', 'back', 'beat'): 6.4990348781533,
#  ('back', 'beat', 'on'): 6.4990348781533,
#  ('beat', 'on', '<unk>'): 6.4990348781533,
#  ('on', '<unk>', 'two'): 6.506531165131227,
#  ('<unk>', 'two', 'and'): 6.4990348781533,
#  ('two', 'and', '<unk>'): 6.4990348781533,
#  ('<s>', '<s>', 'melodies'): 6.806829360392176,
#  ('<s>', 'melodies', 'often'): 6.4990348781533,
#  ('melodies', 'often', '<unk>'): 6.4990348781533,
#  ('often', '<unk>', 'from'): 6.507277712385012,
#  ('<unk>', 'from', '<unk>'): 4.820281565605037,
#  ('from', '<unk>', 'musical'): 6.512487995850419,
#  ('<unk>', 'musical', '<unk>'): 6.09732493780746,
#  ('musical', '<unk>', 'such'): 6.502790045915623,
#  ('<unk>', 'and', '<unk>'): 2.5951333550969995,
#  ('and', '<unk>', 'as'): 5.949339620807311,
#  ('<unk>', 'as', 'well'): 4.915591745409362,
#  ('as', 'well', 'as'): 4.562858987916369,
#  ('well', 'as', 'major'): 6.508023702721733,
#  ('as', 'major', 'and'): 6.500538637835167,
#  ('major', 'and', 'minor'): 6.4990348781533,
#  ('and', 'minor', '<unk>'): 6.4990348781533,
#  ('minor', '<unk>', '</s>'): 6.499787040655854,
#  ('<s>', '<s>', 'harmonies'): 6.806829360392176,
#  ('<s>', 'harmonies', 'range'): 6.4990348781533,
#  ('harmonies', 'range', 'from'): 6.4990348781533,
#  ('range', 'from', 'the'): 6.4990348781533,
#  ('from', 'the', 'common'): 6.530148499002369,
#  ('the', 'common', '<unk>'): 6.4990348781533,
#  ('common', '<unk>', 'to'): 6.500538637835167,
#  ('<unk>', 'to', '<unk>'): 4.194692536056383,
#  ('to', '<unk>', '<unk>'): 4.840601568095995,
#  ('and', '<unk>', 'and'): 5.138409404590982,
#  ('and', '<unk>', '<unk>'): 3.2925827140926516,
#  ('<unk>', '<unk>', '</s>'): 3.455922281351402,
#  ('since', 'the', 'late'): 6.501289670540389,
#  ('the', 'late', '1950s,'): 6.115156019450532,
#  ('late', '1950s,', 'and'): 6.499787040655854,
#  ('1950s,', 'and', 'particularly'): 6.499787040655854,
#  ('and', 'particularly', 'from'): 6.501289670540389,
#  ('particularly', 'from', 'the'): 6.4990348781533,
#  ('from', 'the', 'mid-1960s'): 6.124683390894205,
#  ('the', 'mid-1960s', '<unk>'): 6.502040139618764,
#  ('mid-1960s', '<unk>', 'rock'): 6.4990348781533,
#  ('rock', 'music', 'often'): 6.520621127558696,
#  ('music', 'often', 'used'): 6.4990348781533,
#  ('often', 'used', 'the'): 6.500538637835167,
#  ('used', 'the', 'verse–chorus'): 6.500538637835167,
#  ('the', 'verse–chorus', '<unk>'): 6.4990348781533,
#  ('verse–chorus', '<unk>', 'derived'): 6.499787040655854,
#  ('<unk>', 'derived', 'from'): 6.4990348781533,
#  ('derived', 'from', 'blues'): 6.09732493780746,
#  ('from', 'blues', 'and'): 6.499787040655854,
#  ('blues', 'and', 'folk'): 6.502040139618764,
#  ('and', 'folk', 'music,'): 6.095073529727002,
#  ('folk', 'music,', 'but'): 6.500538637835167,
#  ('music,', 'but', 'there'): 6.499787040655854,
#  ('but', 'there', 'has'): 6.4990348781533,
#  ('there', 'has', 'been'): 6.09432193254769,
#  ('has', 'been', 'considerable'): 6.516932447610842,
#  ('been', 'considerable', '<unk>'): 6.4990348781533,
#  ('considerable', '<unk>', 'from'): 6.4990348781533,
#  ('<unk>', 'from', 'this'): 6.525029657843462,
#  ('from', 'this', '<unk>'): 6.4990348781533,
#  ('this', '<unk>', '</s>'): 6.502790045915623,
#  ('<s>', '<unk>', 'have'): 6.12322353662034,
#  ('<unk>', 'have', 'stressed'): 6.506531165131227,
#  ('have', 'stressed', 'the'): 6.4990348781533,
#  ('stressed', 'the', '<unk>'): 6.4990348781533,
#  ('<unk>', 'and', 'stylistic'): 6.714170529909472,
#  ('and', 'stylistic', '<unk>'): 6.4990348781533,
#  ('stylistic', '<unk>', 'of'): 6.4990348781533,
#  ('<unk>', 'of', 'rock.'): 6.189632112352014,
#  ('of', 'rock.', '</s>'): 5.807391457275221,
#  ('<s>', '<s>', 'because'): 6.401364252284012,
#  ('<s>', 'because', 'of'): 6.499787040655854,
#  ('because', 'of', 'its'): 6.499787040655854,
#  ('of', 'its', 'complex'): 6.502790045915623,
#  ('its', 'complex', 'history'): 6.4990348781533,
#  ('complex', 'history', 'and'): 6.4990348781533,
#  ('history', 'and', 'its'): 6.499787040655854,
#  ('and', 'its', 'tendency'): 6.499787040655854,
#  ('its', 'tendency', 'to'): 6.4990348781533,
#  ('tendency', 'to', '<unk>'): 6.4990348781533,
#  ('to', '<unk>', 'from'): 6.54534966033442,
#  ('<unk>', 'from', 'other'): 6.119564549735298,
#  ('from', 'other', 'musical'): 6.499787040655854,
#  ('other', 'musical', 'and'): 6.500538637835167,
#  ('musical', 'and', 'cultural'): 6.09432193254769,
#  ('and', 'cultural', '<unk>'): 6.499787040655854,
#  ('cultural', '<unk>', 'it'): 6.500538637835167,
#  ('<unk>', 'it', 'has'): 5.595454597770573,
#  ('it', 'has', 'been'): 5.254514743889644,
#  ('has', 'been', 'argued'): 6.516932447610842,
#  ('been', 'argued', 'that'): 6.4990348781533,
#  ('argued', 'that', '<unk>'): 6.500538637835167,
#  ('that', '<unk>', 'is'): 6.508023702721733,
#  ('<unk>', 'is', '<unk>'): 6.501289670540389,
#  ('is', '<unk>', 'to'): 6.501289670540389,
#  ('rock', 'music', 'to'): 6.520621127558696,
#  ('music', 'to', 'a'): 6.500538637835167,
#  ('<unk>', '<unk>', 'musical'): 6.921658184151128,
#  ('musical', '<unk>', '</s>'): 6.502790045915623,
#  ('in', 'the', 'opinion'): 6.60934924316738,
#  ('the', 'opinion', 'of'): 6.4990348781533,
#  ('opinion', 'of', 'music'): 6.4990348781533,
#  ('of', 'music', '<unk>'): 6.501289670540389,
#  ('music', '<unk>', 'robert'): 6.508023702721733,
#  ('<unk>', 'robert', 'christgau,'): 6.4990348781533,
#  ('robert', 'christgau,', '"the'): 6.4990348781533,
#  ('christgau,', '"the', '<unk>'): 6.4990348781533,
#  ('"the', '<unk>', 'rock'): 6.501289670540389,
#  ('<unk>', 'rock', '<unk>'): 5.82452409235233,
#  ('rock', '<unk>', '<unk>'): 5.415359386979701,
#  ('the', '<unk>', 'with'): 5.197882969226266,
#  ('<unk>', 'with', '<unk>'): 5.146767468420836,
#  ('with', '<unk>', 'of'): 6.519884479274924,
#  ('<unk>', 'of', 'modern'): 6.595097220460179,
#  ('of', 'modern', 'technology'): 6.4990348781533,
#  ('modern', 'technology', 'and'): 6.4990348781533,
#  ('technology', 'and', '<unk>'): 6.4990348781533,
#  ('<s>', 'rock', 'and'): 5.815621956411737,
#  ('rock', 'and', 'roll'): 3.773479070980079,
#  ('and', 'roll', 'was'): 6.116627690061988,
#  ('roll', 'was', '<unk>'): 6.499787040655854,
#  ('was', '<unk>', 'as'): 6.507277712385012,
#  ('<unk>', 'as', 'an'): 5.831882477283517,
#  ('as', 'an', '<unk>'): 5.588745664667843,
#  ('an', '<unk>', 'for'): 6.512487995850419,
#  ('<unk>', 'for', 'adolescent'): 6.513230110912307,
#  ('for', 'adolescent', '<unk>'): 6.4990348781533,
#  ('adolescent', '<unk>', '...'): 6.4990348781533,
#  ('<unk>', '...', 'to'): 6.500538637835167,
#  ('...', 'to', 'make'): 6.4990348781533,
#  ('to', 'make', 'rock'): 6.500538637835167,
#  ('make', 'rock', 'and'): 6.4990348781533,
#  ('and', 'roll', 'is'): 6.522092798170152,
#  ('roll', 'is', 'also'): 6.4990348781533,
#  ('is', 'also', 'an'): 6.4990348781533,
#  ('also', 'an', '<unk>'): 6.09432193254769,
#  ('an', '<unk>', 'way'): 6.512487995850419,
#  ('<unk>', 'way', 'to'): 6.4990348781533,
#  ('way', 'to', 'explore'): 6.4990348781533,
#  ('to', 'explore', '<unk>'): 6.499787040655854,
#  ('explore', '<unk>', 'of'): 6.4990348781533,
#  ('<unk>', 'of', 'sex,'): 6.595097220460179,
#  ('of', 'sex,', 'love,'): 6.4990348781533,
#  ('sex,', 'love,', '<unk>'): 6.4990348781533,
#  ('love,', '<unk>', 'and'): 6.4990348781533,
#  ('and', '<unk>', 'to'): 5.389723832871888,
#  ('<unk>', 'and', 'limitations'): 6.714170529909472,
#  ('and', 'limitations', 'of'): 6.4990348781533,
#  ('limitations', 'of', 'the'): 6.4990348781533,
#  ('<unk>', 'and', 'to'): 6.714170529909472,
#  ('and', 'to', 'deal'): 6.4990348781533,
#  ('to', 'deal', 'with'): 6.4990348781533,
#  ('deal', 'with', 'the'): 6.4990348781533,
#  ('with', 'the', '<unk>'): 5.133590118155033,
#  ('and', '<unk>', 'of'): 4.937738709128831,
#  ('<unk>', 'of', '<unk>'): 3.9209485710336502,
#  ('of', '<unk>', 'culture'): 6.147755791434351,
#  ('<unk>', 'culture', '<unk>'): 6.499787040655854,
#  ('culture', '<unk>', '</s>'): 6.499787040655854,
#  ('<s>', '<unk>', 'many'): 6.528688644728503,
#  ('<unk>', 'many', 'earlier'): 6.502040139618764,
#  ('many', 'earlier', 'styles'): 6.4990348781533,
#  ('earlier', 'styles', 'of'): 6.4990348781533,
#  ('styles', 'of', 'popular'): 6.500538637835167,
#  ('of', 'popular', 'music,'): 6.095824562432225,
#  ('popular', 'music,', 'rock'): 6.501289670540389,
#  ('music,', 'rock', 'lyrics'): 6.4990348781533,
#  ('rock', 'lyrics', 'have'): 6.499787040655854,
#  ('lyrics', 'have', '<unk>'): 6.4990348781533,
#  ('have', '<unk>', 'with'): 6.501289670540389,
#  ('with', 'a', 'wide'): 6.507277712385012,
#  ('a', 'wide', 'range'): 5.808892959058818,
#  ('wide', 'range', 'of'): 5.807391457275221,
#  ('range', 'of', '<unk>'): 6.502040139618764,
#  ('of', '<unk>', 'including'): 6.147755791434351,
#  ('<unk>', 'including', 'romantic'): 6.51025834052315,
#  ('including', 'romantic', 'love,'): 6.4990348781533,
#  ('romantic', 'love,', 'sex,'): 6.4990348781533,
#  ('love,', 'sex,', 'rebellion'): 6.4990348781533,
#  ('sex,', 'rebellion', 'against'): 6.4990348781533,
#  ('rebellion', 'against', '"the'): 6.499787040655854,
#  ('against', '"the', '<unk>'): 6.4990348781533,
#  ('"the', '<unk>', 'social'): 6.501289670540389,
#  ('<unk>', 'social', '<unk>'): 6.095073529727002,
#  ('social', '<unk>', 'and'): 5.809642865355679,
#  ('<unk>', 'and', 'life'): 6.714170529909472,
#  ('and', 'life', 'styles.'): 6.4990348781533,
#  ('life', 'styles.', '</s>'): 6.4990348781533,
#  ('<s>', '<s>', 'these'): 5.708217071724067,
#  ('<s>', 'these', 'themes'): 6.502040139618764,
#  ('these', 'themes', 'were'): 6.4990348781533,
#  ('themes', 'were', 'inherited'): 6.4990348781533,
#  ('were', 'inherited', 'from'): 6.4990348781533,
#  ('inherited', 'from', 'a'): 6.4990348781533,
#  ('from', 'a', 'variety'): 6.500538637835167,
#  ('a', 'variety', 'of'): 5.403427850950654,
#  ('variety', 'of', 'sources'): 6.503539390274405,
#  ('of', 'sources', 'such'): 6.4990348781533,
#  ('sources', 'such', 'as'): 6.4990348781533,
#  ('<unk>', '<unk>', 'pop'): 6.921658184151128,
#  ('<unk>', 'pop', '<unk>'): 6.500538637835167,
#  ('pop', '<unk>', 'folk'): 6.4990348781533,
#  ('<unk>', 'folk', 'music,'): 6.499787040655854,
#  ('folk', 'music,', 'and'): 6.500538637835167,
#  ('music,', 'and', 'rhythm'): 6.502790045915623,
#  ('rhythm', 'and', '<unk>'): 6.504288173536645,
#  ('<s>', '<s>', 'christgau'): 6.401364252284012,
#  ('<s>', 'christgau', '<unk>'): 6.499787040655854,
#  ('christgau', '<unk>', 'rock'): 6.4990348781533,
#  ('<unk>', 'rock', 'lyrics'): 6.517671272912275,
#  ('rock', 'lyrics', 'as'): 6.499787040655854,
#  ('lyrics', 'as', 'a'): 6.4990348781533,
#  ('as', 'a', '<unk>'): 4.911919321157098,
#  ('<unk>', '<unk>', 'with'): 5.216910091912704,
#  ('<unk>', 'with', 'simple'): 6.533061829540727,
#  ('with', 'simple', '<unk>'): 6.4990348781533,
#  ('simple', '<unk>', 'and'): 6.095824562432225,
#  ('and', '<unk>', 'that'): 5.949339620807311,
#  ('<unk>', 'that', "rock's"): 6.513230110912307,
#  ('that', "rock's", '<unk>'): 6.4990348781533,
#  ("rock's", '<unk>', '<unk>'): 6.500538637835167,
#  ('<unk>', '<unk>', 'to'): 4.975748035095815,
#  ('<unk>', 'to', 'music,'): 6.54606779321986,
#  ('to', 'music,', '<unk>'): 6.4990348781533,
#  ('music,', '<unk>', 'more'): 6.502040139618764,
#  ('<unk>', 'more', '<unk>'): 6.503539390274405,
#  ('more', '<unk>', '<unk>'): 5.820824495087865,
#  ('<s>', 'the', '<unk>'): 5.049143502766242,
#  ('of', '<unk>', '<unk>'): 4.201845642379038,
#  ('and', 'often', 'middle'): 6.502040139618764,
#  ('often', 'middle', 'class'): 6.4990348781533,
#  ('middle', 'class', 'musicians'): 6.4990348781533,
#  ('class', 'musicians', 'in'): 6.4990348781533,
#  ('musicians', 'in', 'rock'): 6.499787040655854,
#  ('rock', 'music', 'has'): 5.422008838890586,
#  ('music', 'has', 'often'): 6.502040139618764,
#  ('often', 'been', 'noted,'): 6.499787040655854,
#  ('been', 'noted,', 'and'): 6.4990348781533,
#  ('noted,', 'and', 'rock'): 6.4990348781533,
#  ('and', 'rock', 'has'): 6.09807428216624,
#  ('rock', 'has', 'been'): 5.588745664667843,
#  ('has', 'been', 'seen'): 5.130638086490952,
#  ('been', 'seen', 'as'): 4.716264233493678,
#  ('seen', 'as', 'an'): 5.822305976840308,
#  ('an', '<unk>', 'of'): 5.413875707182309,
#  ('<unk>', 'of', 'black'): 6.595097220460179,
#  ('of', 'black', 'musical'): 6.4990348781533,
#  ('black', 'musical', 'forms'): 6.499787040655854,
#  ('musical', 'forms', 'for'): 6.4990348781533,
#  ('forms', 'for', 'a'): 6.4990348781533,
#  ('for', 'a', '<unk>'): 5.58799744166249,
#  ('a', '<unk>', 'white'): 6.557488331338734,
#  ('<unk>', 'white', 'and'): 6.4990348781533,
#  ('white', 'and', 'largely'): 6.4990348781533,
#  ('and', 'largely', 'male'): 6.4990348781533,
#  ('largely', 'male', '<unk>'): 6.4990348781533,
#  ('male', '<unk>', '</s>'): 6.499787040655854,
#  ('<s>', '<s>', 'as'): 6.806829360392176,
#  ('<s>', 'as', 'a'): 6.4990348781533,
#  ('a', '<unk>', 'it'): 6.557488331338734,
#  ('it', 'has', 'also'): 6.507277712385012,
#  ('has', 'also', 'been'): 5.807391457275221,
#  ('also', 'been', 'seen'): 6.095824562432225,
#  ('been', 'seen', 'to'): 6.508023702721733,
#  ('seen', 'to', '<unk>'): 6.4990348781533,
#  ('<unk>', 'the', 'concerns'): 6.577861357721047,
#  ('the', 'concerns', 'of'): 6.4990348781533,
#  ('concerns', 'of', 'this'): 6.4990348781533,
#  ...}

# %%
def choise(model, prev_w, i, options_bad):
    w_bad = ['<unk>'] + options_bad
    w_options = ((ngram[-1], prob) for ngram, prob in model.items() if ngram[:-1]==prev_w)
    w_options = filter(lambda word: word[0] not in w_bad, w_options)
    w_options = sorted(w_options, key=lambda word: word[1], reverse=True)
    if len(w_options) == 0:
        return ('</s>', 1)
    else:
        return w_options[0 if prev_w != () and prev_w[-1] != '<s>' else i]

# %%
def generate(model, n, num_s, len_s=[10, 20]):
    for i in range(num_s):
        sent, prob = ['<s>'] * max(1, n-1), 1
        while sent[-1] != '</s>':
            prev_w = () if n == 1 else tuple(sent[-(n-1):])
            options_bad = sent + (['</s>'] if len(sent) < len_s[0] else [])
            next_w, next_prob = choise(model, prev_w, i, options_bad)
            sent.append(next_w)
            prob += next_prob

            if len(sent) >= len_s[1]:
                sent.append('</s>')

        print(' '.join(sent), 1/prob)

# %%
generate(prob, 3, 5)
# Out:
# <s> <s> further fusion subgenres have since emerged, including pop-punk, electronic rock, rap </s> 0.013550515520893976
# <s> <s> melodies often </s> 0.06533443550881976
# <s> <s> harmonies range from the mid-1960s, particularly in california and texas. </s> 0.013730218879121516
# <s> <s> as a rock group with electric bass guitar, which emerged in its modern form </s> 0.01080918121714382
# <s> <s> christgau, writing in christgau's record guide: the </s> 0.02127971206202656
